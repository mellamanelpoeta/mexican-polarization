# %% [markdown]
# # Demo
#
# > This is a demo of how the library works

# %%
from mexican_polarization.Loader import Loader
from mexican_polarization.Analyzer import Analyzer
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
loader = Loader(csv = '/Users/gerardoguerrero/mexican-polarization/nbs/datalake/2024-01-11-11-10-22-CST-Historical-Report-Medios-Anti-4T-democracia-2018-01-01--2024-01-01.csv', virtue_dict = "virtue.txt", vice_dict= "vice.txt")

# %%
loader.process_csv(text_cols=['Page Name', 'Message'], num_cols=['Total Interactions'], date_cols=['Post Created'])

# %%
loader.processed
# Out:
#        Page Name                                            Message  \
# 0        milenio  politicairremediable en las ultimas decadas he...
# 1        latinus  la imparcialidad del tepjf no debe estar sujet...
# 2        latinus  los proximos comicios pondran a prueba al trib...
# 3        milenio  apunteincomodos la politica se ha caricaturiza...
# 4     reformacom  opinion el 2024 sera crucial para la democraci...
# ...          ...                                                ...
# 2246  reformacom  porsinoloviste el proclamado presidente encarg...
# 2247     milenio  el presidente de bolivia dijo que las garras d...
# 2248     milenio  los mexicanos no podemos aceptar que este enga...
# 2249     milenio  los diputados que aprobaron la disminucion de ...
# 2250     milenio  por cuarta vez desde que se establecio la demo...
#
#      Total Interactions             Post Created
# 0                    18  2023-12-30 11:35:37 CST
# 1                   129  2023-12-28 21:33:39 CST
# ...

# %%
analyzer = Analyzer(loader)

# %%
df = analyzer.moral_words_count('Message')
df[(df ['Vice words count'] > 0) | (df['Virtue words count'] > 0)]
# Out:
#        Page Name                                            Message  \
# 0        milenio  politicairremediable en las ultimas decadas he...
# 3        milenio  apunteincomodos la politica se ha caricaturiza...
# 7        latinus  eu agrega a su lista de corruptos a tres fisca...
# 10       latinus  en opinion de denise dresser es la democracia ...
# 11       milenio  pensandolobien el verdadero sentido de la demo...
# ...          ...                                                ...
# 2239     milenio  las consecuencias sociales son inquietantes el...
# 2242  reformacom  porsinoloviste si el el gobernador quiere dedi...
# 2243  reformacom  enterate en una carta dirigida a claudia ruiz ...
# 2245     milenio                    tienen una verdadera democracia
# 2249     milenio  los diputados que aprobaron la disminucion de ...
#
#      Total Interactions             Post Created  Vice words count  \
# 0                    18  2023-12-30 11:35:37 CST                 0
# ...

# %%
df.groupby('Page Name').sum().reset_index().sort_values('Vice words count',ascending=False)[['Page Name', 'Vice words count', 'Virtue words count']]
# Out:
#        Page Name  Vice words count  Virtue words count
# 1        milenio               155                 245
# 3     reformacom               100                 121
# 2  radio formula                73                 105
# 0        latinus                38                  36
# 4      tv azteca                 0                   0

# %%
df[df['Page Name'] == 'tv azteca']
# Out:
#       Page Name                                            Message  \
# 1225  tv azteca                                                nan
# 1368  tv azteca  el presidente amlo dijo que la democracia esta...
# 1775  tv azteca                                                nan
#
#      Total Interactions             Post Created  Vice words count  \
# 1225                  5  2022-04-01 15:00:42 CST                 0
# 1368                267  2021-12-21 14:17:09 CST                 0
# 1775                 14  2021-04-10 20:40:13 CDT                 0
#
#       Virtue words count
# 1225                   0
# 1368                   0
# 1775                   0
